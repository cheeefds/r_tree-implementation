# %%
import RTree
from rtree_show import show_rtree

# %%
rt = RTree.RTree(maxentries=3, minentries=2)

# %%
rt.insert_data(mbr=(0,1,0,1), data="A")
rt.insert_data(mbr=(1,2,1,2), data="B")
rt.insert_data(mbr=(2,3,2,3), data="C")
rt.insert_data(mbr=(3,4,3,4), data="D")

# %%
show_rtree(rt.root,0)
# Out:
# Level 0 : [0, 2, 0, 2] Node(2) [2, 4, 2, 4] Node(2)
# Level 1 : (0, 1, 0, 1) A (1, 2, 1, 2) B
# Level 1 : (3, 4, 3, 4) D (2, 3, 2, 3) C

# %%
rt.insert_data(mbr=(5,6,5,6), data="E")

# %%
show_rtree(rt.root,0)
# Out:
# Level 0 : [0, 2, 0, 2] Node(2) [2, 6, 2, 6] Node(3)
# Level 1 : (0, 1, 0, 1) A (1, 2, 1, 2) B
# Level 1 : (3, 4, 3, 4) D (2, 3, 2, 3) C (5, 6, 5, 6) E

# %%
rt.insert_data(mbr=(7,8,7,8), data="F")

# %%
show_rtree(rt.root,0)
# Out:
# Level 0 : [0, 2, 0, 2] Node(2) [2, 4, 2, 4] Node(2) [5, 8, 5, 8] Node(2)
# Level 1 : (0, 1, 0, 1) A (1, 2, 1, 2) B
# Level 1 : (2, 3, 2, 3) C (3, 4, 3, 4) D
# Level 1 : (7, 8, 7, 8) F (5, 6, 5, 6) E

# %%
rt.insert_data(mbr=(-1,0,-1,0), data="G")

# %%
show_rtree(rt.root,0)
# Out:
# Level 0 : [-1, 2, -1, 2] Node(3) [2, 4, 2, 4] Node(2) [5, 8, 5, 8] Node(2)
# Level 1 : (0, 1, 0, 1) A (1, 2, 1, 2) B (-1, 0, -1, 0) G
# Level 1 : (2, 3, 2, 3) C (3, 4, 3, 4) D
# Level 1 : (7, 8, 7, 8) F (5, 6, 5, 6) E

# %%
rt.insert_data(mbr=(11,12,11,12), data="H")

# %%
show_rtree(rt.root,0)
# Out:
# Level 0 : [-1, 2, -1, 2] Node(3) [2, 4, 2, 4] Node(2) [5, 12, 5, 12] Node(3)
# Level 1 : (0, 1, 0, 1) A (1, 2, 1, 2) B (-1, 0, -1, 0) G
# Level 1 : (2, 3, 2, 3) C (3, 4, 3, 4) D
# Level 1 : (7, 8, 7, 8) F (5, 6, 5, 6) E (11, 12, 11, 12) H

# %%
rt.insert_data(mbr=(12,13,12,13), data="I")
show_rtree(rt.root,0)
# Out:
# Level 0 : [-1, 4, -1, 4] Node(2) [5, 13, 5, 13] Node(2)
# Level 1 : [-1, 2, -1, 2] Node(3) [2, 4, 2, 4] Node(2)
# Level 2 : (0, 1, 0, 1) A (1, 2, 1, 2) B (-1, 0, -1, 0) G
# Level 2 : (2, 3, 2, 3) C (3, 4, 3, 4) D
# Level 1 : [11, 13, 11, 13] Node(2) [5, 8, 5, 8] Node(2)
# Level 2 : (12, 13, 12, 13) I (11, 12, 11, 12) H
# Level 2 : (5, 6, 5, 6) E (7, 8, 7, 8) F

# %%
rt.insert_data(mbr=(-2,-3,-2,-3), data="J")
show_rtree(rt.root,0)
# Out:
# Level 0 : [-2, 4, -2, 4] Node(3) [5, 13, 5, 13] Node(2)
# Level 1 : [0, 2, 0, 2] Node(2) [2, 4, 2, 4] Node(2) [-2, 0, -2, 0] Node(2)
# Level 2 : (1, 2, 1, 2) B (0, 1, 0, 1) A
# Level 2 : (2, 3, 2, 3) C (3, 4, 3, 4) D
# Level 2 : (-2, -3, -2, -3) J (-1, 0, -1, 0) G
# Level 1 : [11, 13, 11, 13] Node(2) [5, 8, 5, 8] Node(2)
# Level 2 : (12, 13, 12, 13) I (11, 12, 11, 12) H
# Level 2 : (5, 6, 5, 6) E (7, 8, 7, 8) F
